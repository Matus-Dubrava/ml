# %% [markdown]
# # Mean, Median & Mode

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("seaborn-whitegrid")

# %%
incomes = np.random.normal(27000, 15000, 10000)
np.mean(incomes)
# Out:
# 27090.203104157812

# %%
plt.hist(incomes, bins=50, edgecolor="k");

# %%
np.median(incomes)
# Out:
# 27068.24269422447

# %%
incomes = np.append(incomes, [1_000_000_000])
print(f"mean: {np.mean(incomes)}")
print(f"median: {np.median(incomes)}")
# Out:
# mean: 127077.49535462237
# median: 27071.588184881322

# %%
from scipy import stats
ages = np.random.randint(18, 90, 500)
stats.mode(ages)
# Out:
# ModeResult(mode=array([89]), count=array([13]))

# %% [markdown]
# # Variance & Standard Deviation

# %%
data = np.array([1, 4, 5, 4, 8])

mean = np.mean(data)
variance = np.sum((data - mean) ** 2) / len(data)
std = np.sqrt(variance)
mean, variance, std
# Out:
# (4.4, 5.04, 2.244994432064365)

# %%
incomes = np.random.normal(100, 20, 1000)
mean, std = np.mean(incomes), np.std(incomes)
mean, std
# Out:
# (99.62304569161762, 20.873092113087143)

# %%
plt.hist(incomes, bins=50, edgecolor="k")
plt.plot([mean - std] * 2, [0, 60], color="red")
plt.plot([mean + std] * 2, [0, 60], color="red")
plt.plot([mean - 2 * std] * 2, [0, 60], color="red")
plt.plot([mean + 2 * std] * 2, [0, 60], color="red");
plt.plot([mean - 3 * std] * 2, [0, 60], color="red")
plt.plot([mean + 3 * std] * 2, [0, 60], color="red");

# %% [markdown]
# # probability distributions

# %% [markdown]
# ### normal distribution

# %%
from scipy.stats import norm

x = np.arange(-3, 3, 0.001)

plt.plot(x, norm.pdf(x));

# %% [markdown]
# ### exponential distribution

# %%
from scipy.stats import expon

x = np.arange(0, 10, 0.001)
plt.plot(x, expon.pdf(x));

# %% [markdown]
# ### binomial distribution

# %%
from scipy.stats import binom

n, p = 10, 0.5
x = np.arange(0, 10, 0.001)
plt.plot(x, binom.pmf(x, n, p));

# %% [markdown]
# ### poisson distribution

# %%
from scipy.stats import poisson

mu = 500
x = np.arange(400, 600, 0.5)
plt.plot(x, poisson.pmf(x, mu));

# %% [markdown]
# # percentiles

# %%
x = np.random.normal(0, 0.5, 10000)
plt.hist(x, bins=50, edgecolor="k");

# %%
# median = 50th percentile
np.percentile(x, 50), np.median(x)
# Out:
# (0.0022133638397103146, 0.0022133638397103146)

# %%
# 90th percentile
np.percentile(x, 90)
# Out:
# 0.6364893334050563

# %%
# 20th percentile
np.percentile(x, 20)
# Out:
# -0.4130875300850238

# %% [markdown]
# # Moments: Mean, Variance, Skew, Kurtosis

# %%
x = np.random.normal(0, 0.5, 10000)
plt.hist(x, bins=50, edgecolor="k");

# %%
# mean (1st moment)
np.mean(x)
# Out:
# -0.0006709001175533672

# %%
# variance (2nd moment)
np.var(x)
# Out:
# 0.24616130114651505

# %%
# skew (3rd moment)
import scipy.stats as sp
sp.skew(x)
# Out:
# -0.019019178403586058

# %%
# kurtosis (4th moment)
sp.kurtosis(x)
# Out:
# 0.0689684385669409
